# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Data Cleaning Extras
# #### Goals for this step
# - Remove null bathrooms and bedrooms from data set

# %%
df = pd.read_pickle("C:/Users/Admin/Documents/ironhack/AirBnB_data/airbnb_listings_countries.pkl")

# %%
df
# Out:
#        Listing ID                                              Name  \
# 0         5534229                           A 2 Passi da San Pietro
# 1         5903406                              cosy small apartment
# 2         5203533                    Rummelig lejl i hjertet af KBH
# 3         8858475   Modern; spacious and warm; with its own balcony
# 4         4215511                 Nice room; Bohemian Cph; N�rrebro
# ...           ...                                               ...
# 379050   20810636             Modern Apartment in a Great Location!
# 379051    9563852        CHARMING STUDIO IN BARBES; NEAR MONTMARTRE
# 379052    5841088               Bright 1Bedroom Apartment & Rooftop
# 379053   12157261  Chambre douillette; appart lumineux; rue St-Jean
# 379054   11225183               Hollywood Pool Home w/ Pool House!!
#
#           Host ID          Host Name  Host Response Rate  Host Is Superhost  \
# ...

# %% [markdown]
# We will remove rows where there are null values for bedrooms and bathrooms.

# %%
df = df[(~df["Bathrooms"].isna())]

# %%
df
# Out:
#        Listing ID                                              Name  \
# 0         5534229                           A 2 Passi da San Pietro
# 1         5903406                              cosy small apartment
# 2         5203533                    Rummelig lejl i hjertet af KBH
# 3         8858475   Modern; spacious and warm; with its own balcony
# 4         4215511                 Nice room; Bohemian Cph; N�rrebro
# ...           ...                                               ...
# 379050   20810636             Modern Apartment in a Great Location!
# 379051    9563852        CHARMING STUDIO IN BARBES; NEAR MONTMARTRE
# 379052    5841088               Bright 1Bedroom Apartment & Rooftop
# 379053   12157261  Chambre douillette; appart lumineux; rue St-Jean
# 379054   11225183               Hollywood Pool Home w/ Pool House!!
#
#           Host ID          Host Name  Host Response Rate  Host Is Superhost  \
# ...

# %%
df = df[(~df["Bedrooms"].isna())]

# %%
df
# Out:
#        Listing ID                                              Name  \
# 0         5534229                           A 2 Passi da San Pietro
# 1         5903406                              cosy small apartment
# 2         5203533                    Rummelig lejl i hjertet af KBH
# 3         8858475   Modern; spacious and warm; with its own balcony
# 4         4215511                 Nice room; Bohemian Cph; N�rrebro
# ...           ...                                               ...
# 379050   20810636             Modern Apartment in a Great Location!
# 379051    9563852        CHARMING STUDIO IN BARBES; NEAR MONTMARTRE
# 379052    5841088               Bright 1Bedroom Apartment & Rooftop
# 379053   12157261  Chambre douillette; appart lumineux; rue St-Jean
# 379054   11225183               Hollywood Pool Home w/ Pool House!!
#
#           Host ID          Host Name  Host Response Rate  Host Is Superhost  \
# ...

# %%
df = df.reset_index(drop=True)

# %%
df
# Out:
#        Listing ID                                              Name  \
# 0         5534229                           A 2 Passi da San Pietro
# 1         5903406                              cosy small apartment
# 2         5203533                    Rummelig lejl i hjertet af KBH
# 3         8858475   Modern; spacious and warm; with its own balcony
# 4         4215511                 Nice room; Bohemian Cph; N�rrebro
# ...           ...                                               ...
# 379050   20810636             Modern Apartment in a Great Location!
# 379051    9563852        CHARMING STUDIO IN BARBES; NEAR MONTMARTRE
# 379052    5841088               Bright 1Bedroom Apartment & Rooftop
# 379053   12157261  Chambre douillette; appart lumineux; rue St-Jean
# 379054   11225183               Hollywood Pool Home w/ Pool House!!
#
#           Host ID          Host Name  Host Response Rate  Host Is Superhost  \
# ...

# %%
# df.to_pickle("C:/Users/Admin/Documents/ironhack/AirBnB_data/airbnb_listings_countries.pkl")

# %% [markdown]
# We will do the same for the US dataframe.

# %%
df_usa = pd.read_pickle("C:/Users/Admin/Documents/ironhack/AirBnB_data/airbnb_listings_usa.pkl")

# %%
df_usa
# Out:
#        Listing ID                                               Name  \
# 0         4581256                     Beacon hill small bedroom (__)
# 1         3967592                  Minutes to Boston-Near Beach 71-3
# 2        12205354                Artsy apartment near Moscone Center
# 3         3230382   Large master bedroom & covered patio; __________
# 4        10491563                     ___downtown____soma__loft_____
# ...           ...                                                ...
# 108306   13764162  Beautiful Home in Encino. 15 Min from Everything!
# 108307    8867269                    Studio apartment in west campus
# 108308   19824378  Private 2 Bedroom Luxury Townhouse; Chestnut Hill
# 108309   20810636              Modern Apartment in a Great Location!
# 108310   11225183                Hollywood Pool Home w/ Pool House!!
#
#           Host ID          Host Name  Host Response Rate  Host Is Superhost  \
# ...

# %%
df_usa = df_usa[(~df_usa["Bathrooms"].isna())]

# %%
df_usa
# Out:
#        Listing ID                                               Name  \
# 0         4581256                     Beacon hill small bedroom (__)
# 1         3967592                  Minutes to Boston-Near Beach 71-3
# 2        12205354                Artsy apartment near Moscone Center
# 3         3230382   Large master bedroom & covered patio; __________
# 4        10491563                     ___downtown____soma__loft_____
# ...           ...                                                ...
# 108306   13764162  Beautiful Home in Encino. 15 Min from Everything!
# 108307    8867269                    Studio apartment in west campus
# 108308   19824378  Private 2 Bedroom Luxury Townhouse; Chestnut Hill
# 108309   20810636              Modern Apartment in a Great Location!
# 108310   11225183                Hollywood Pool Home w/ Pool House!!
#
#           Host ID          Host Name  Host Response Rate  Host Is Superhost  \
# ...

# %%
df_usa = df_usa[(~df_usa["Bedrooms"].isna())]

# %%
df_usa
# Out:
#        Listing ID                                               Name  \
# 0         4581256                     Beacon hill small bedroom (__)
# 1         3967592                  Minutes to Boston-Near Beach 71-3
# 2        12205354                Artsy apartment near Moscone Center
# 3         3230382   Large master bedroom & covered patio; __________
# 4        10491563                     ___downtown____soma__loft_____
# ...           ...                                                ...
# 108306   13764162  Beautiful Home in Encino. 15 Min from Everything!
# 108307    8867269                    Studio apartment in west campus
# 108308   19824378  Private 2 Bedroom Luxury Townhouse; Chestnut Hill
# 108309   20810636              Modern Apartment in a Great Location!
# 108310   11225183                Hollywood Pool Home w/ Pool House!!
#
#           Host ID          Host Name  Host Response Rate  Host Is Superhost  \
# ...

# %%
# df_usa.to_pickle("C:/Users/Admin/Documents/ironhack/AirBnB_data/airbnb_listings_usa.pkl")
