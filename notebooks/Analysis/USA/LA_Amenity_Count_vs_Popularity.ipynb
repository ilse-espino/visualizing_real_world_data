# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
sns.set(style="white")

# %% [markdown]
# ## Amenity Count vs Popularity (reviews per month) for LA listings
# #### Goals for this step
# - Plot amenity count vs reviews per month to see if there is a relationship between the most popular AirBnB listings and number of amenities

# %%
df = pd.read_csv("C:/Users/Admin/Documents/ironhack/AirBnB_data/LA_Listings.csv", encoding = "ISO-8859-1", low_memory=False)

# %%
df.columns
# Out:
# Index(['Listing ID', 'Name', 'Host ID', 'Host Name', 'Host Response Rate',
#        'Host Is Superhost', 'Host total listings count', 'Street', 'City',
#        'Neighbourhood cleansed', 'State', 'Country', 'latitude', 'longitude',
#        'Property type', 'Room type', 'Accommodates', 'Bathrooms', 'Bedrooms',
#        'Amenities', 'Price', 'Minimum nights', 'Maximum nights',
#        'Availability 365', 'Calendar last scraped', 'Number of reviews',
#        'Last Review Date', 'Review Scores Rating', 'Review Scores Accuracy',
#        'Review Scores Cleanliness', 'Review Scores Checkin',
#        'Review Scores Communication', 'Review Scores Location',
#        'Review Scores Value', 'Reviews per month'],
#       dtype='object')

# %%
df = df[['Listing ID', 'Host ID', 'Host Response Rate',
       'Host Is Superhost', 'Host total listings count', 'City',
       'Neighbourhood cleansed', 'State', 'Country', 'latitude', 'longitude',
       'Property type', 'Room type', 'Accommodates', 'Bathrooms', 'Bedrooms',
       'Amenities', 'Price', 'Minimum nights', 'Maximum nights',
       'Availability 365', 'Calendar last scraped', 'Number of reviews',
       'Last Review Date', 'Review Scores Rating', 'Review Scores Accuracy',
       'Review Scores Cleanliness', 'Review Scores Checkin',
       'Review Scores Communication', 'Review Scores Location',
       'Review Scores Value', 'Reviews per month']]

# %%
df.head()
# Out:
#    Listing ID    Host ID  Host Response Rate  Host Is Superhost  \
# 0    11085215   57460111                 NaN              False
# 1     3230382   15878447                 1.0               True
# 2    18211034  125720858                 1.0              False
# 3    12209039   38037399                 1.0              False
# 4    10339306   52290241                 0.0              False
#
#    Host total listings count         City Neighbourhood cleansed State  \
# 0                        3.0  Los Angeles     West Puente Valley    CA
# 1                        9.0  Los Angeles          Monterey Park    CA
# 2                        1.0  Los Angeles              Hawthorne    CA
# 3                        2.0  Los Angeles            Diamond Bar    CA
# 4                        1.0  Los Angeles            Temple City    CA
#
#          Country     latitude  ...  Number of reviews Last Review Date  \
# 0  United States  34.05689088  ...                  0              NaN
# 1  United States  34.06032707  ...                 38         12/28/16
# 2  United States  33.92183162  ...                  0              NaN
# 3  United States   34.0275231  ...                  0              NaN
# 4  United States  34.09453005  ...                  1          7/23/16
#
#   Review Scores Rating  Review Scores Accuracy  Review Scores Cleanliness  \
# 0                    0                       0                          0
# 1                   95                      10                          9
# 2                    0                       0                          0
# 3                    0                       0                          0
# 4                  100                      10                         10
#
#    Review Scores Checkin Review Scores Communication  Review Scores Location  \
# 0                      0                           0                       0
# 1                      9                          10                      10
# 2                      0                           0                       0
# 3                      0                           0                       0
# 4                     10                          10                      10
#
#    Review Scores Value  Reviews per month
# 0                    0               0.00
# 1                    9               1.11
# 2                    0               0.00
# 3                    0               0.00
# 4                   10               0.11
#
# [5 rows x 32 columns]

# %% [markdown]
# First we will look at the null values on this data set and try to remove information that is not needed.

# %%
df.isnull().sum(axis = 0)
# Out:
# Listing ID                         0
# Host ID                            0
# Host Response Rate             34241
# Host Is Superhost                  0
# Host total listings count         14
# City                               0
# Neighbourhood cleansed             0
# State                              0
# Country                            0
# latitude                           0
# longitude                          0
# Property type                      0
# Room type                          0
# Accommodates                   28717
# Bathrooms                      28813
# Bedrooms                       28717
# Amenities                      29142
# Price                              0
# Minimum nights                     0
# Maximum nights                 28717
# Availability 365                   0
# Calendar last scraped          28717
# Number of reviews                  0
# Last Review Date               13832
# Review Scores Rating               0
# Review Scores Accuracy             0
# Review Scores Cleanliness          0
# Review Scores Checkin              0
# Review Scores Communication        0
# Review Scores Location             0
# Review Scores Value                0
# Reviews per month                  0
# dtype: int64

# %% [markdown]
# Since our main focus is the amenity count, we will remove rows that have null values for amenities.

# %%
df = df.loc[~df["Amenities"].isnull()].reset_index(drop=True)

# %%
df.isnull().sum(axis = 0)
# Out:
# Listing ID                        0
# Host ID                           0
# Host Response Rate             5314
# Host Is Superhost                 0
# Host total listings count        14
# City                              0
# Neighbourhood cleansed            0
# State                             0
# Country                           0
# latitude                          0
# longitude                         0
# Property type                     0
# Room type                         0
# Accommodates                      0
# Bathrooms                        74
# Bedrooms                          0
# Amenities                         0
# Price                             0
# Minimum nights                    0
# Maximum nights                    0
# Availability 365                  0
# Calendar last scraped             0
# Number of reviews                 0
# Last Review Date               6876
# Review Scores Rating              0
# Review Scores Accuracy            0
# Review Scores Cleanliness         0
# Review Scores Checkin             0
# Review Scores Communication       0
# Review Scores Location            0
# Review Scores Value               0
# Reviews per month                 0
# dtype: int64

# %% [markdown]
# We will look at a general overview of the reviews per month.

# %%
df["Reviews per month"].describe()
# Out:
# count    30723.000000
# mean         1.452839
# std          1.952038
# min          0.000000
# 25%          0.070000
# 50%          0.690000
# 75%          2.140000
# max         90.000000
# Name: Reviews per month, dtype: float64

# %% [markdown]
# We will look at listings that have 1 or more reviews per month, indicating that they had at least one guest per month.

# %%
df_reviews_pm = df[df["Reviews per month"] >= 1].reset_index(drop=True)

# %% [markdown]
# We will create a column that indicates the number of amenities on each listing.

# %%
df_reviews_pm["Amenities_List"] = df_reviews_pm["Amenities"].str.split(";")

# %%
df_reviews_pm["Amenities_Count"] = df_reviews_pm["Amenities_List"].str.len()

# %%
df_reviews_pm.head()
# Out:
#    Listing ID   Host ID  Host Response Rate  Host Is Superhost  \
# 0     3230382  15878447                1.00               True
# 1    17545953  74732009                1.00              False
# 2    10513135  47987624                1.00              False
# 3     7422793  38884077                1.00              False
# 4     4432082  22994518                0.91              False
#
#    Host total listings count         City Neighbourhood cleansed State  \
# 0                        9.0  Los Angeles          Monterey Park    CA
# 1                        5.0  Los Angeles        Rowland Heights    CA
# 2                        6.0  Los Angeles               El Monte    CA
# 3                        2.0  Los Angeles       Hacienda Heights    CA
# 4                        3.0  Los Angeles       Hacienda Heights    CA
#
#          Country     latitude  ...  Review Scores Rating  \
# 0  United States  34.06032707  ...                    95
# 1  United States  33.98801281  ...                    90
# 2  United States  34.09355084  ...                    95
# 3  United States  33.99188283  ...                    80
# 4  United States  34.00232128  ...                    84
#
#   Review Scores Accuracy Review Scores Cleanliness  Review Scores Checkin  \
# 0                     10                         9                      9
# 1                     10                         9                     10
# 2                     10                        10                      9
# 3                      6                         6                      8
# 4                      8                         8                      9
#
#    Review Scores Communication  Review Scores Location Review Scores Value  \
# 0                           10                      10                   9
# 1                            8                       9                  10
# 2                            9                      10                  10
# 3                            8                       8                   8
# 4                            9                       9                   9
#
#    Reviews per month                                     Amenities_List  \
# 0               1.11  [Internet, Wireless Internet, Air conditioning...
# 1               1.18  [TV, Internet, Wireless Internet, Air conditio...
# 2               3.03  [Internet, Wireless Internet, Air conditioning...
# 3               1.00  [Internet, Wireless Internet, Air conditioning...
# 4               1.08  [Wireless Internet, Air conditioning, Pool, Fr...
#
#    Amenities_Count
# 0               14
# 1               22
# 2               17
# 3               14
# 4               16
#
# [5 rows x 34 columns]

# %%
len(df_reviews_pm["Amenities_List"][0])
# Out:
# 14

# %% [markdown]
# We will now take a look at the top neighbourhoods and will focus on the top 10 neighbourhoods with more listings.

# %%
df_reviews_pm["Neighbourhood cleansed"].value_counts().sort_values(ascending=False).head(10)
# Out:
# Venice             1122
# Hollywood          1065
# Downtown            522
# Long Beach          483
# Santa Monica        422
# West Hollywood      372
# Silver Lake         345
# Hollywood Hills     325
# Mid-Wilshire        303
# Koreatown           296
# Name: Neighbourhood cleansed, dtype: int64

# %%
neighbourhoods = list(df_reviews_pm["Neighbourhood cleansed"].value_counts().sort_values(ascending=False).head(10).index)
neighbourhoods
# Out:
# ['Venice',
#  'Hollywood',
#  'Downtown',
#  'Long Beach',
#  'Santa Monica',
#  'West Hollywood',
#  'Silver Lake',
#  'Hollywood Hills',
#  'Mid-Wilshire',
#  'Koreatown']

# %%
df_top_n = df_reviews_pm[df_reviews_pm["Neighbourhood cleansed"].isin(neighbourhoods)].reset_index(drop=True)

# %%
fig, ax = plt.subplots(figsize=(12,8))
ax = sns.lineplot(data=df_top_n,
                 x="Amenities_Count",
                 y="Reviews per month",
                 hue="Neighbourhood cleansed")

# %% [markdown]
# The plot for amenities count vs average reviews per month for the top 10 neighbourhoods with more listings looks like the first graphs we plotted for the countries listings.

# %%
fig, ax = plt.subplots(figsize=(12,8))
ax = sns.scatterplot(data=df_reviews_pm,
                 x="Amenities_Count",
                 y="Reviews per month")

# %% [markdown]
# On the scatter plot we can see that there is no clear relationship between the amenities counts and the reviews per month, there seems to be a cluster.

# %%
fig, ax = plt.subplots(figsize=(12,8))
ax = sns.scatterplot(data=df_reviews_pm,
                 x="Amenities_Count",
                 y="Review Scores Rating")

# %% [markdown]
# The same can bee sen for the number of amenities vs review socres rating, most reviews remein 80 and 100, as well as the first plots made on the amenities vs review score notebook.
#
# We will look at an specific neighbourhood to see if there is a more clear relationship within a higher granularity level.

# %%
df_venice = df_reviews_pm[df_reviews_pm["Neighbourhood cleansed"] == "Venice"].reset_index(drop=True)

# %%
fig, ax = plt.subplots(figsize=(12,8))
ax = sns.scatterplot(data=df_venice,
                 x="Amenities_Count",
                 y="Reviews per month")

# %% [markdown]
# There is still no clear relationship between this two variables.

# %%
df_venice["const"] = 1

X = df_venice[["Amenities_Count", "const"]]
y = df_venice["Price"]
model = sm.OLS(y, X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.083
# Model:                            OLS   Adj. R-squared:                  0.082
# Method:                 Least Squares   F-statistic:                     100.8
# Date:                Fri, 01 May 2020   Prob (F-statistic):           9.17e-23
# Time:                        09:14:08   Log-Likelihood:                -6906.9
# No. Observations:                1122   AIC:                         1.382e+04
# Df Residuals:                    1120   BIC:                         1.383e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Amenities_Count     6.9836      0.696     10.038      0.000       5.619       8.349
# const              45.5466     13.908      3.275      0.001      18.258      72.835
# ==============================================================================
# Omnibus:                      497.739   Durbin-Watson:                   1.911
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2512.906
# Skew:                           2.045   Prob(JB):                         0.00
# Kurtosis:                       9.085   Cond. No.                         81.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# The adjusted R2 for a specific neighbourhood is 0.083, meaning that there is a weak relationship between price and the number of amenities since there is a lot of variation between them.
