# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Data Cleaning Step 3.2
# #### Goals for this step
# - Create an individual data frame for amenities as columns, 1 indicating True and 0 indicating False

# %%
df = pd.read_pickle("C:/Users/Admin/Documents/ironhack/AirBnB_data/airbnb_listings_countries.pkl")

# %%
df.head()
# Out:
#   Listing ID                                             Name   Host ID  \
# 0    5534229                          A 2 Passi da San Pietro  28697142
# 1    5903406                             cosy small apartment   1853799
# 2    5203533                   Rummelig lejl i hjertet af KBH  24801534
# 3    8858475  Modern; spacious and warm; with its own balcony   3000397
# 4    4215511                Nice room; Bohemian Cph; N�rrebro    126020
#
#   Host Name  Host Response Rate  Host Is Superhost  Host total listings count  \
# 0  Veronica               100.0              False                        5.0
# 1  Veronika                88.0              False                        2.0
# 2  Marianne               100.0              False                        1.0
# 3     Lasse               100.0               True                        1.0
# 4       Lea               100.0               True                        2.0
#
#    Country   latitude  longitude  ... Last Review Date Review Scores Rating  \
# 0    Italy  41.895878  12.454430  ...       2015-08-29                 90.0
# 1  Austria  48.246033  16.340743  ...       2017-09-09                 87.0
# 2  Denmark  55.681579  12.562770  ...       2016-07-26                100.0
# 3  Denmark  55.708413  12.596737  ...       2017-05-07                100.0
# 4  Denmark  55.687506  12.558365  ...       2017-05-08                 94.0
#
#    Review Scores Accuracy  Review Scores Cleanliness  Review Scores Checkin  \
# 0                     9.0                       10.0                    8.0
# 1                     9.0                       10.0                   10.0
# 2                    10.0                       10.0                   10.0
# 3                    10.0                       10.0                   10.0
# 4                    10.0                       10.0                    9.0
#
#   Review Scores Communication  Review Scores Location  Review Scores Value  \
# 0                         8.0                     9.0                  9.0
# 1                        10.0                    10.0                  8.0
# 2                        10.0                    10.0                 10.0
# 3                        10.0                     9.0                 10.0
# 4                        10.0                    10.0                 10.0
#
#    Reviews per month  Amenity_Count
# 0               0.08             11
# 1               0.27             12
# 2               0.28              8
# 3               0.79             23
# 4               1.40             10
#
# [5 rows x 32 columns]

# %%
amenities = df["Amenities"].str.split(";")

# %%
amenities_count = []

for amenity in amenities:
    for i in range(len(amenity)):
        amenities_count.append(amenity[i])

# %%
amenities_df = pd.DataFrame(amenities_count)[0].value_counts()

# %%
amenities_df
# Out:
# Wireless Internet      369416
# Kitchen                356725
# Heating                352303
# Essentials             339938
# Washer                 284751
#                         ...
# Body soap                   1
# Hand soap                   1
# Bath towel                  1
# Hand or paper towel         1
# Toilet paper                1
# Name: 0, Length: 152, dtype: int64

# %% [markdown]
# We will only use the Top 100 amenities

# %%
amenities_df = amenities_df.head(100)

# %%
amenities_top = amenities_df.reset_index().rename(columns={"index":"amenity"})["amenity"]

# %% [markdown]
# Creating blank amenities data frame

# %%
amenities_df = pd.DataFrame(columns=(amenities_top), index=range(df.shape[0]))

# %%
amenities_df
# Out:
# amenity Wireless Internet Kitchen Heating Essentials Washer   TV Internet  \
# 0                     NaN     NaN     NaN        NaN    NaN  NaN      NaN
# 1                     NaN     NaN     NaN        NaN    NaN  NaN      NaN
# 2                     NaN     NaN     NaN        NaN    NaN  NaN      NaN
# 3                     NaN     NaN     NaN        NaN    NaN  NaN      NaN
# 4                     NaN     NaN     NaN        NaN    NaN  NaN      NaN
# ...                   ...     ...     ...        ...    ...  ...      ...
# 385034                NaN     NaN     NaN        NaN    NaN  NaN      NaN
# 385035                NaN     NaN     NaN        NaN    NaN  NaN      NaN
# 385036                NaN     NaN     NaN        NaN    NaN  NaN      NaN
# 385037                NaN     NaN     NaN        NaN    NaN  NaN      NaN
# 385038                NaN     NaN     NaN        NaN    NaN  NaN      NaN
#
# amenity Hangers Shampoo Smoke detector  ... Well-lit path to entrance  \
# 0           NaN     NaN            NaN  ...                       NaN
# 1           NaN     NaN            NaN  ...                       NaN
# 2           NaN     NaN            NaN  ...                       NaN
# 3           NaN     NaN            NaN  ...                       NaN
# 4           NaN     NaN            NaN  ...                       NaN
# ...         ...     ...            ...  ...                       ...
# 385034      NaN     NaN            NaN  ...                       NaN
# 385035      NaN     NaN            NaN  ...                       NaN
# 385036      NaN     NaN            NaN  ...                       NaN
# 385037      NaN     NaN            NaN  ...                       NaN
# 385038      NaN     NaN            NaN  ...                       NaN
#
# amenity Single level home Babysitter recommendations BBQ grill Other pet(s)  \
# 0                     NaN                        NaN       NaN          NaN
# 1                     NaN                        NaN       NaN          NaN
# 2                     NaN                        NaN       NaN          NaN
# 3                     NaN                        NaN       NaN          NaN
# 4                     NaN                        NaN       NaN          NaN
# ...                   ...                        ...       ...          ...
# 385034                NaN                        NaN       NaN          NaN
# 385035                NaN                        NaN       NaN          NaN
# 385036                NaN                        NaN       NaN          NaN
# 385037                NaN                        NaN       NaN          NaN
# 385038                NaN                        NaN       NaN          NaN
#
# amenity Smoking Allowed Smart lock Suitable for Events Ethernet connection  \
# 0                   NaN        NaN                 NaN                 NaN
# 1                   NaN        NaN                 NaN                 NaN
# 2                   NaN        NaN                 NaN                 NaN
# 3                   NaN        NaN                 NaN                 NaN
# 4                   NaN        NaN                 NaN                 NaN
# ...                 ...        ...                 ...                 ...
# 385034              NaN        NaN                 NaN                 NaN
# 385035              NaN        NaN                 NaN                 NaN
# 385036              NaN        NaN                 NaN                 NaN
# 385037              NaN        NaN                 NaN                 NaN
# 385038              NaN        NaN                 NaN                 NaN
#
# amenity Baby bath
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 385034        NaN
# 385035        NaN
# 385036        NaN
# 385037        NaN
# 385038        NaN
#
# [385039 rows x 100 columns]

# %%
rows = range(df.shape[0])

def amenities_func(row, df, amenities):
    for i in amenities[row]:
        if i in df.columns:
            df.loc[row, i] = 1
    return df

# %%
amenities_func(0, amenities_df, amenities)
# Out:
# amenity Wireless Internet Kitchen Heating Essentials Washer   TV Internet  \
# 0                       1     NaN       1          1    NaN    1        1
# 1                     NaN     NaN     NaN        NaN    NaN  NaN      NaN
# 2                     NaN     NaN     NaN        NaN    NaN  NaN      NaN
# 3                     NaN     NaN     NaN        NaN    NaN  NaN      NaN
# 4                     NaN     NaN     NaN        NaN    NaN  NaN      NaN
# ...                   ...     ...     ...        ...    ...  ...      ...
# 385034                NaN     NaN     NaN        NaN    NaN  NaN      NaN
# 385035                NaN     NaN     NaN        NaN    NaN  NaN      NaN
# 385036                NaN     NaN     NaN        NaN    NaN  NaN      NaN
# 385037                NaN     NaN     NaN        NaN    NaN  NaN      NaN
# 385038                NaN     NaN     NaN        NaN    NaN  NaN      NaN
#
# amenity Hangers Shampoo Smoke detector  ... Well-lit path to entrance  \
# 0           NaN       1            NaN  ...                       NaN
# 1           NaN     NaN            NaN  ...                       NaN
# 2           NaN     NaN            NaN  ...                       NaN
# 3           NaN     NaN            NaN  ...                       NaN
# 4           NaN     NaN            NaN  ...                       NaN
# ...         ...     ...            ...  ...                       ...
# 385034      NaN     NaN            NaN  ...                       NaN
# 385035      NaN     NaN            NaN  ...                       NaN
# 385036      NaN     NaN            NaN  ...                       NaN
# 385037      NaN     NaN            NaN  ...                       NaN
# 385038      NaN     NaN            NaN  ...                       NaN
#
# amenity Single level home Babysitter recommendations BBQ grill Other pet(s)  \
# 0                     NaN                        NaN       NaN          NaN
# 1                     NaN                        NaN       NaN          NaN
# 2                     NaN                        NaN       NaN          NaN
# 3                     NaN                        NaN       NaN          NaN
# 4                     NaN                        NaN       NaN          NaN
# ...                   ...                        ...       ...          ...
# 385034                NaN                        NaN       NaN          NaN
# 385035                NaN                        NaN       NaN          NaN
# 385036                NaN                        NaN       NaN          NaN
# 385037                NaN                        NaN       NaN          NaN
# 385038                NaN                        NaN       NaN          NaN
#
# amenity Smoking Allowed Smart lock Suitable for Events Ethernet connection  \
# 0                   NaN        NaN                 NaN                 NaN
# 1                   NaN        NaN                 NaN                 NaN
# 2                   NaN        NaN                 NaN                 NaN
# 3                   NaN        NaN                 NaN                 NaN
# 4                   NaN        NaN                 NaN                 NaN
# ...                 ...        ...                 ...                 ...
# 385034              NaN        NaN                 NaN                 NaN
# 385035              NaN        NaN                 NaN                 NaN
# 385036              NaN        NaN                 NaN                 NaN
# 385037              NaN        NaN                 NaN                 NaN
# 385038              NaN        NaN                 NaN                 NaN
#
# amenity Baby bath
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 385034        NaN
# 385035        NaN
# 385036        NaN
# 385037        NaN
# 385038        NaN
#
# [385039 rows x 100 columns]

# %%
amenities[0]
# Out:
# ['TV',
#  'Internet',
#  'Wireless Internet',
#  'Air conditioning',
#  'Smoking allowed',
#  'Pets allowed',
#  'Heating',
#  'First aid kit',
#  'Fire extinguisher',
#  'Essentials',
#  'Shampoo']

# %%
amenities_df.sum(axis=1)[0]
# Out:
# 11.0

# %%
for i in rows:
    amenities_df = amenities_func(i, amenities_df, amenities)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-f69b9d6a5c33> in <module>
#       1 for i in rows:
# ----> 2     amenities_df = amenities_func(i, amenities_df, amenities)
#
# <ipython-input-15-3e3efb7ffceb> in amenities_func(row, df, amenities)
#       4     for i in amenities[row]:
#       5         if i in df.columns:
# ----> 6             df.loc[row, i] = 1
#       7     return df
#
# ~\.conda\envs\backpack_banana\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     669             key = com.apply_if_callable(key, self.obj)
#     670         indexer = self._get_setitem_indexer(key)
# --> 671         self._setitem_with_indexer(indexer, value)
#     672
#     673     def _validate_key(self, key, axis: int):
#
# ~\.conda\envs\backpack_banana\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer(self, indexer, value)
#    1063             # actually do the set
#    1064             self.obj._consolidate_inplace()
# -> 1065             self.obj._data = self.obj._data.setitem(indexer=indexer, value=value)
#    1066             self.obj._maybe_update_cacher(clear=True)
#    1067
#
# ~\.conda\envs\backpack_banana\lib\site-packages\pandas\core\internals\managers.py in setitem(self, **kwargs)
#     559
#     560     def setitem(self, **kwargs):
# --> 561         return self.apply("setitem", **kwargs)
#     562
#     563     def putmask(self, **kwargs):
#
# ~\.conda\envs\backpack_banana\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, filter, **kwargs)
#     445         if len(result_blocks) == 0:
#     446             return self.make_empty(self.axes)
# --> 447         bm = type(self)(result_blocks, self.axes, do_integrity_check=False)
#     448         return bm
#     449
#
# ~\.conda\envs\backpack_banana\lib\site-packages\pandas\core\internals\managers.py in __init__(self, blocks, axes, do_integrity_check)
#     141         self._consolidate_check()
#     142
# --> 143         self._rebuild_blknos_and_blklocs()
#     144
#     145     def make_empty(self, axes=None):
#
# ~\.conda\envs\backpack_banana\lib\site-packages\pandas\core\internals\managers.py in _rebuild_blknos_and_blklocs(self)
#     222             rl = blk.mgr_locs
#     223             new_blknos[rl.indexer] = blkno
# --> 224             new_blklocs[rl.indexer] = np.arange(len(rl))
#     225
#     226         if (new_blknos == -1).any():
#
# KeyboardInterrupt:

# %%
amenities_df
